# %%
import pytesseract
import cv2
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread('F:\\Shubhangi.Shiledar\\OCR Dataset\\dataset\\degraded\\de2.jpg')
plt.figure(figsize=(10,10))
plt.imshow(img, cmap ='gray')

# %%
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'
img=cv2.imread('F:\\Shubhangi.Shiledar\\OCR Dataset\\dataset\\degraded\\de2.jpg')
text = pytesseract.image_to_string(img)
print(text)
# Out:
# Ogled po Gorenskem.
# Poljanska dolina in pot skox njoj
#
# (Konee.) x
# Polagoma so okrenemo okoll gritkal
# raemne #0 asim océm y desui dali
# PUMrija, Na konou gori ponoano. stojt x1
# rede mali stolpicek v zrak moli;» pod gt
# siecli s:sunprosiizn: seonta.,y hhabage!
